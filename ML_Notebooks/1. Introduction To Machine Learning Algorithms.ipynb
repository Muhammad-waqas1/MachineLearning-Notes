# %% [markdown]
# # 1. Introduction To Machine Learning Algorithms

# %% [markdown]
# AI vs ML vs DL vs DS
# ---------------------
#
# 1. AI : It can do its tasks without any Human interventions
# - Netflix
# - Self-Driving
# - Amazon.in
#
# 2. ML : Is Subset of AI that provides stats tools to analyze, visualize, forecasting and to do predictions
#
# 3. DL : Is Subset of ML that mimic the human brain using multilayer neural network
#
# 4. DS : Is Part of Everything. Responsive creating an AI application using any method possible

# %% [markdown]
# Supervised Learning Algorithms
# ---------------------------------
#
# ### 🔹 Regression
#
# *   **Linear Regression**
#
# *   **Polynomial Regression**
#
# *   **Ridge Regression** (L2 Regularization)
#
# *   **Lasso Regression** (L1 Regularization)
#
# *   **Elastic Net Regression**
#
# *   **Decision Tree Regressor**
#
# *   **Random Forest Regressor**
#
# *   **Gradient Boosting Regressor**
#
#     *   XGBoost Regressor
#
#     *   LightGBM Regressor
#
#     *   CatBoost Regressor
#
# *   **Support Vector Regressor (SVR)**
# *   **ANN**
# *   **RNN**
#
#
# ### 🔹 Classification
#
# *   **Logistic Regression**
#
# *   **k-Nearest Neighbors (k-NN)**
#
# *   **Naive Bayes**
#
#     *   Gaussian NB
#
#     *   Multinomial NB
#
#     *   Bernoulli NB
#
# *   **Support Vector Machine (SVM)**
#
# *   **Decision Tree Classifier**
#
# *   **Random Forest Classifier**
#
# *   **Gradient Boosting Classifier**
#
#     *   XGBoost
#
#     *   LightGBM
#
#     *   CatBoost
#
# *   **ANN**
# *   **CNN**
#
#
# Unsupervised Learning Algorithms
# -----------------------------------
#
# ### 🔹 Clustering
#
# *   **K-Means Clustering**
#
# *   **Hierarchical Clustering**
#
#     *   Agglomerative
#
#     *   Divisive
#
# *   **DBSCAN** (Density-Based Spatial Clustering)
#
# *   **OPTICS** (Advanced Density-Based Clustering)
#
# *   **Mean Shift**
#
# *   **Gaussian Mixture Models (GMM)**
#
#
# Semi-Supervised Learning Algorithms
# --------------------------------------
#
# > Note: These often sit between supervised and unsupervised techniques.
#
# *   **Reinforcement Learning**
#
# *   **Dimensionality Reduction** (Technically unsupervised, but often grouped here)
#
#     *   PCA (Principal Component Analysis)
#
#     *   t-SNE (t-distributed Stochastic Neighbor Embedding)
#
#     *   UMAP (Uniform Manifold Approximation and Projection)
#
#     *   LDA (Linear Discriminant Analysis)
